# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/data sets/Market.csv")

# %%
df=pd.DataFrame(data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  110253.000000  110252.000000  110251.000000  110250.000000
# mean     7658.561932    7704.538416    7608.129749    7657.740822
# std      9011.455529    9066.605458    8954.536718    9011.555549
# min        54.869999      54.869999      54.869999      54.869999
# 25%      1855.060059    1864.687469    1844.015015    1855.347473
# 50%      5194.399902    5226.750000    5154.299805    5194.889892
# 75%     10134.299810   10207.827635   10060.369630   10134.867430
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume
# count  110244.000000  1.102530e+05
# mean     7657.982529  1.273975e+09
# std      9011.723572  4.315783e+09
# min        54.869999  0.000000e+00
# 25%      1855.057556  0.000000e+00
# 50%      5195.699951  4.329000e+05
# 75%     10135.512452  1.734314e+08
# max     68775.062500  9.440374e+10

# %%
plt.scatter(df['Open'],df['Adj Close'])

plt.xlabel('open price')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
year=pd.to_datetime(df.Date).dt.year  ####changing to timeseries

# %%
df.insert(loc=2 , column='year', value=year)  ### adding year as a new columnd to df

# %%
df  #### see the new look of df
# Out:
#        Index        Date  year         Open         High          Low  \
# 0        NYA  12/31/1965  1965   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966  1966   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966  1966   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966  1966   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966  1966   532.070007   532.070007   532.070007
# ...      ...         ...   ...          ...          ...          ...
# 112452  N100   5/27/2021  2021  1241.119995  1251.910034  1241.119995
# 112453  N100   5/28/2021  2021  1249.469971  1259.209961  1249.030029
# 112454  N100   5/31/2021  2021  1256.079956  1258.880005  1248.140015
# 112455  N100    6/1/2021  2021  1254.609985  1265.660034  1254.609985
# 112456  N100    6/2/2021  2021  1258.489990  1263.709961  1258.239990
#
#               Close    Adj Close       Volume
# 0        528.690002   528.690002          0.0
# ...

# %%
df=df.loc[df['Index']=='NYA']  #######considering only NYA Index

# %%
df  ######see the new look of df
# Out:
#       Index        Date  year          Open          High           Low  \
# 0       NYA  12/31/1965  1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966  1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966  1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966  1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966  1966    532.070007    532.070007    532.070007
# ...     ...         ...   ...           ...           ...           ...
# 13943   NYA   5/24/2021  2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# ...

# %%
df.drop('Volume',axis=1,inplace=True)  ###remove volume column
# Out:
# C:\Users\sama\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#       Index        Date  year          Open          High           Low  \
# 0       NYA  12/31/1965  1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966  1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966  1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966  1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966  1966    532.070007    532.070007    532.070007
# ...     ...         ...   ...           ...           ...           ...
# 13943   NYA   5/24/2021  2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# ...

# %%
df.dropna()
# Out:
#       Index        Date  year          Open          High           Low  \
# 0       NYA  12/31/1965  1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966  1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966  1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966  1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966  1966    532.070007    532.070007    532.070007
# ...     ...         ...   ...           ...           ...           ...
# 13943   NYA   5/24/2021  2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# ...

# %%
df.isna().sum().sum()  ### counting Nan values in df
# Out:
# 20

# %%
df.dropna(axis=0 , how='any', inplace = True) ### removing Nan values of df
# Out:
# <ipython-input-18-867e140555e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis=0 , how='any', inplace = True) ### removing Nan values of df

# %%
df.isna().sum().sum()  #### checking for missing values
# Out:
# 0

# %%
df
# Out:
#       Index        Date  year          Open          High           Low  \
# 0       NYA  12/31/1965  1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966  1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966  1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966  1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966  1966    532.070007    532.070007    532.070007
# ...     ...         ...   ...           ...           ...           ...
# 13943   NYA   5/24/2021  2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# ...

# %%
df[['Open','Close','High','Low','Adj Close']].astype('int', copy=False) #### change df numeric types to integer
# Out:
#         Open  Close   High    Low  Adj Close
# 0        528    528    528    528        528
# 1        527    527    527    527        527
# 2        527    527    527    527        527
# 3        531    531    531    531        531
# 4        532    532    532    532        532
# ...      ...    ...    ...    ...        ...
# 13943  16375  16464  16508  16375      16464
# 13944  16464  16390  16525  16375      16390
# 13945  16390  16451  16466  16388      16451
# 13946  16451  16531  16546  16451      16531
# 13947  16531  16555  16588  16531      16555
#
# [13932 rows x 5 columns]

# %%
plt.scatter(df['year'],df['Adj Close'])
plt.title("Adj Close vs. year")
plt.xlabel('year')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt.scatter(df['Open'],df['Adj Close'])
plt.title("Open Price vs. year")
plt.xlabel('Open')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt.scatter(df['Close'],df['Adj Close'])
plt.title("Close price vs. Adj Close")
plt.xlabel('Close Price')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
#### defining an Array named "ay" to append year in the form of yearly
ay=[]
for i in range(1965,2021,1):
    ay.append(i)
ay.append(2021)    
ay
# Out:
# [1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['year'],df['Adj Close'])
plt.title("Adj Close vs. year")
plt.xlabel('year')
plt.xticks(ticks=ay , rotation = 90)
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
df
# Out:
#       Index        Date  year          Open          High           Low  \
# 0       NYA  12/31/1965  1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966  1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966  1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966  1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966  1966    532.070007    532.070007    532.070007
# ...     ...         ...   ...           ...           ...           ...
# 13943   NYA   5/24/2021  2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close
# 0        528.690002    528.690002
# ...

# %%
np.mean(df['Adj Close']) ###checking the avarege of adj close to have an idea for noise recognition
# Out:
# 4456.806822718825

# %%
low = df['Close'].nsmallest(2)
low
# Out:
# 2181    347.769989
# 2182    347.880005
# Name: Close, dtype: float64

# %%
df[['Open','Close','High','Low','Adj Close']]=df[['Open','Close','High','Low','Adj Close']].astype('int', copy=False) #### change df numeric types to integer
# Out:
# C:\Users\sama\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df
# Out:
#       Index        Date  year   Open   High    Low  Close  Adj Close
# 0       NYA  12/31/1965  1965    528    528    528    528        528
# 1       NYA    1/3/1966  1966    527    527    527    527        527
# 2       NYA    1/4/1966  1966    527    527    527    527        527
# 3       NYA    1/5/1966  1966    531    531    531    531        531
# 4       NYA    1/6/1966  1966    532    532    532    532        532
# ...     ...         ...   ...    ...    ...    ...    ...        ...
# 13943   NYA   5/24/2021  2021  16375  16508  16375  16464      16464
# 13944   NYA   5/25/2021  2021  16464  16525  16375  16390      16390
# 13945   NYA   5/26/2021  2021  16390  16466  16388  16451      16451
# 13946   NYA   5/27/2021  2021  16451  16546  16451  16531      16531
# 13947   NYA   5/28/2021  2021  16531  16588  16531  16555      16555
#
# [13932 rows x 8 columns]

# %%
low=df['Close'].nsmallest(3)
low
# Out:
# 2181    347
# 2182    347
# 2178    353
# Name: Close, dtype: int32

# %%
i=df[df['year']==1969].index

# %%
###remove year 1969 which is noise
df=df.drop(i)
df
# Out:
#       Index        Date    year   Open   High    Low  Close  Adj Close
# 0       NYA  12/31/1965  1965.0    528    528    528    528        528
# 1       NYA    1/3/1966  1966.0    527    527    527    527        527
# 2       NYA    1/4/1966  1966.0    527    527    527    527        527
# 3       NYA    1/5/1966  1966.0    531    531    531    531        531
# 4       NYA    1/6/1966  1966.0    532    532    532    532        532
# ...     ...         ...     ...    ...    ...    ...    ...        ...
# 13943   NYA   5/24/2021  2021.0  16375  16508  16375  16464      16464
# 13944   NYA   5/25/2021  2021.0  16464  16525  16375  16390      16390
# 13945   NYA   5/26/2021  2021.0  16390  16466  16388  16451      16451
# 13946   NYA   5/27/2021  2021.0  16451  16546  16451  16531      16531
# 13947   NYA   5/28/2021  2021.0  16531  16588  16531  16555      16555
#
# [13683 rows x 8 columns]

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['year'],df['Adj Close'])
plt.title("Adj Close vs. year")
plt.xlabel('year')
plt.xticks(ticks=ay , rotation = 90)
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
i1=df[df['year']==1965].index
i2=df[df['year']==1966].index
i3=df[df['year']==1967].index
i4=df[df['year']==1968].index
i5=df[df['year']==1970].index

# %%
####remove years[1965....1970] 
df=df.drop(i1)
df=df.drop(i2)
df=df.drop(i3)
df=df.drop(i4)
df=df.drop(i5)

# %%
####new scatter without niose 
plt. figure (figsize=(14,10))
plt.scatter(df['year'],df['Adj Close'])
plt.title("Adj Close vs. year")
plt.xlabel('year')
plt.xticks(ticks=ay , rotation = 90)
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['Open'],df['Adj Close'])
plt.title("Adj Close vs. Open")
plt.xlabel('Open')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['Close'],df['Adj Close'])
plt.title("Adj Close vs. Close")
plt.xlabel('Close')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['High'],df['Adj Close'])
plt.title("Adj Close vs. High")
plt.xlabel('High')
plt.ylabel('Adj Close')
plt.grid()
plt.show()

# %%
plt. figure (figsize=(14,10))
plt.scatter(df['Low'],df['Adj Close'])
plt.title("Adj Close vs. Low")
plt.xlabel('Low')
plt.ylabel('Adj Close')
plt.grid()
plt.show()
